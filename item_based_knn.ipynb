# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('/content/drive/MyDrive/Video_Games_5.json.gz')

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'style', 'image'],
#       dtype='object')
# (497577, 12)

# %%
count = df.groupby("asin", as_index=False).count()
mean = df.groupby("asin", as_index=False).mean()

dfMerged = pd.merge(df, count, how='right', on=['asin'])

dfMerged["totalReviewers"] = dfMerged["reviewerID_y"]
dfMerged["overallScore"] = dfMerged["overall_x"]
dfMerged["summaryReview"] = dfMerged["summary_x"]

dfNew = dfMerged[['asin','summaryReview','overallScore',"totalReviewers"]]

dfMerged = dfMerged.sort_values(by='totalReviewers', ascending=False)
dfCount = dfMerged[dfMerged.totalReviewers >= 50]

dfProductReview = df.groupby("asin", as_index=False).mean()
ProductReviewSummary = dfCount.groupby("asin")["summaryReview"].apply(list)
ProductReviewSummary = pd.DataFrame(ProductReviewSummary)

# %%
import re
import string
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer

ProductReviewSummary.to_csv("ProductReviewSummary.csv")
df3 = pd.read_csv("ProductReviewSummary.csv")
df3 = pd.merge(df3, dfProductReview, on="asin", how='inner')
df3 = df3[['asin','summaryReview','overall']]

regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = reviewText.lower()
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

df3["summaryClean"] = df3["summaryReview"].apply(cleanReviews)
df3 = df3.drop_duplicates(['overall'], keep='last')
df3 = df3.reset_index()

reviews = df3["summaryClean"] 
countVector = CountVectorizer(max_features = 300, stop_words='english') 
transformedReviews = countVector.fit_transform(reviews) 

dfReviews = DataFrame(transformedReviews.A, columns=countVector.get_feature_names())
dfReviews = dfReviews.astype(int)

# %%
import numpy as np

X = np.array(dfReviews)

tpercent = 0.9
tsize = int(np.floor(tpercent * len(dfReviews)))
dfReviews_train = X[:tsize]
dfReviews_test = X[tsize:]

lentrain = len(dfReviews_train)
lentest = len(dfReviews_test)

print(lentrain, lentest)
# Out:
# 1594 178

# %%
from sklearn.neighbors import NearestNeighbors

neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(dfReviews_train)

distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
from sklearn import neighbors
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 3
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)

print(classification_report(df5_test_target, knnpreds_test))
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         1
#            3       0.41      0.33      0.36        40
#            4       0.82      0.87      0.84       137
#
#     accuracy                           0.74       178
#    macro avg       0.41      0.40      0.40       178
# weighted avg       0.72      0.74      0.73       178
#
# 0.7415730337078652
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for i in range(lentest):
    a = neighbor.kneighbors([dfReviews_test[i]])
    related_product_list = a[1]

    first_related_product = [item[0] for item in related_product_list]
    first_related_product = str(first_related_product).strip('[]')
    first_related_product = int(first_related_product)
    second_related_product = [item[1] for item in related_product_list]
    second_related_product = str(second_related_product).strip('[]')
    second_related_product = int(second_related_product)
    
    print ("Based on product reviews, for ", df3["asin"][lentrain + i] ," average rating is ",df3["overall"][lentrain + i])
    print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
    print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
    print ("-----------------------------------------------------------")
# Out:
# Based on product reviews, for  B00ZGT8ILI  average rating is  4.547169811320755
# The first similar product is  B00LH6CBA8  average rating is  4.098039215686274
# The second similar product is  B008OQTS0U  average rating is  4.545454545454546
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJ20YQO  average rating is  3.7333333333333334
# The first similar product is  B002ELCV00  average rating is  3.9186991869918697
# The second similar product is  B00LLIQS6U  average rating is  3.7761194029850746
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJ211Q6  average rating is  4.04054054054054
# The first similar product is  B0022TNO7S  average rating is  4.177083333333333
# The second similar product is  B00XK9OVSU  average rating is  4.365168539325842
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJBSCJQ  average rating is  4.337662337662338
# The first similar product is  B004UHSGUA  average rating is  3.784313725490196
# The second similar product is  B001UWGBC8  average rating is  4.103448275862069
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJBT0SS  average rating is  3.870967741935484
# The first similar product is  B000G82KU4  average rating is  4.120689655172414
# The second similar product is  B000PS1HMM  average rating is  3.6271186440677967
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJEIS2Y  average rating is  4.280373831775701
# The first similar product is  B0037LTTRO  average rating is  4.075757575757576
# The second similar product is  B0076ZPYPI  average rating is  4.383928571428571
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJEIVB2  average rating is  4.020979020979021
# The first similar product is  B00JUFT1G0  average rating is  4.078125
# The second similar product is  B00DFT0WVU  average rating is  4.2772277227722775
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJEOTYK  average rating is  4.17741935483871
# The first similar product is  B00KVP3OY8  average rating is  4.188679245283019
# The second similar product is  B00MTWV0RO  average rating is  4.2592592592592595
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJRHSRW  average rating is  4.319444444444445
# The first similar product is  B00LMRL00O  average rating is  4.3768115942028984
# The second similar product is  B008U2XE9O  average rating is  4.153846153846154
# -----------------------------------------------------------
# Based on product reviews, for  B00ZJRHSZO  average rating is  3.1552795031055902
# The first similar product is  B0017O5K0I  average rating is  3.95
# The second similar product is  B000NJBD90  average rating is  3.9753086419753085
# -----------------------------------------------------------
# Based on product reviews, for  B00ZM5ON88  average rating is  4.295081967213115
# The first similar product is  B00KVPC0O8  average rating is  4.288461538461538
# The second similar product is  B00CX7FMDS  average rating is  4.423728813559322
# -----------------------------------------------------------
# Based on product reviews, for  B00ZM5OXD8  average rating is  4.319327731092437
# The first similar product is  B005FDUSTA  average rating is  4.61
# The second similar product is  B00DFT0WVU  average rating is  4.2772277227722775
# -----------------------------------------------------------
# Based on product reviews, for  B00ZM6I1DU  average rating is  4.365384615384615
# The first similar product is  B000FDOTIQ  average rating is  3.76
# The second similar product is  B003O6E7DI  average rating is  4.672413793103448
# -----------------------------------------------------------
# Based on product reviews, for  B00ZM6I932  average rating is  3.392523364485981
# The first similar product is  B00KVL0SIM  average rating is  3.5694444444444446
# The second similar product is  B0085L2T14  average rating is  4.1525423728813555
# -----------------------------------------------------------
# Based on product reviews, for  B00ZMBLKPG  average rating is  4.395348837209302
# The first similar product is  B00XK9OVSU  average rating is  4.365168539325842
# The second similar product is  B00DC9SWWE  average rating is  3.9047619047619047
# -----------------------------------------------------------
# Based on product reviews, for  B00ZMBMO06  average rating is  4.407407407407407
# The first similar product is  B001G33V8S  average rating is  4.38728323699422
# The second similar product is  B00CTKHXFO  average rating is  4.781609195402299
# -----------------------------------------------------------
# Based on product reviews, for  B00ZO1SO08  average rating is  4.02
# The first similar product is  B000038ABO  average rating is  4.314814814814815
# The second similar product is  B00109KMRQ  average rating is  4.592592592592593
# -----------------------------------------------------------
# Based on product reviews, for  B00ZOETH8I  average rating is  4.385964912280702
# The first similar product is  B00K2O54V4  average rating is  4.3559322033898304
# The second similar product is  B00NASF4MS  average rating is  4.446153846153846
# -----------------------------------------------------------
# Based on product reviews, for  B00ZPQZMUM  average rating is  3.904
# The first similar product is  B00X8Y18U6  average rating is  4.543689320388349
# The second similar product is  B00JAPIXX2  average rating is  4.360544217687075
# -----------------------------------------------------------
# Based on product reviews, for  B00ZPTMX60  average rating is  4.210810810810811
# The first similar product is  B00SX9UD8E  average rating is  4.728571428571429
# The second similar product is  B00KME8K7O  average rating is  3.6804733727810652
# -----------------------------------------------------------
# Based on product reviews, for  B00ZPZQKIG  average rating is  3.2439024390243905
# The first similar product is  B00BQWTGIS  average rating is  3.449275362318841
# The second similar product is  B00J6DLPLK  average rating is  4.134328358208955
# -----------------------------------------------------------
# Based on product reviews, for  B00ZQ2YFFI  average rating is  4.685185185185185
# The first similar product is  B00DFT92EI  average rating is  3.830508474576271
# The second similar product is  B0029MAXR2  average rating is  4.4411764705882355
# -----------------------------------------------------------
# Based on product reviews, for  B00ZQB28XK  average rating is  2.905759162303665
# The first similar product is  B005WWZUQ0  average rating is  3.1713147410358564
# The second similar product is  B00D2ZK1IG  average rating is  4.294117647058823
# -----------------------------------------------------------
# Based on product reviews, for  B00ZQBLNP4  average rating is  3.9448818897637796
# The first similar product is  B00ERDGMT4  average rating is  4.661971830985915
# The second similar product is  B00I19TXNC  average rating is  4.091836734693878
# -----------------------------------------------------------
# Based on product reviews, for  B00ZQC73O8  average rating is  4.729249011857707
# The first similar product is  B00KVR4HEC  average rating is  4.270506108202444
# The second similar product is  B00WTI3JPE  average rating is  4.432225063938619
# -----------------------------------------------------------
# Based on product reviews, for  B00ZRZTT3W  average rating is  3.848314606741573
# The first similar product is  B005C2D2MO  average rating is  4.328571428571428
# The second similar product is  B00QXJFE08  average rating is  2.77027027027027
# -----------------------------------------------------------
# Based on product reviews, for  B00ZS15FVA  average rating is  4.364583333333333
# The first similar product is  B00BAWXD88  average rating is  4.814159292035399
# The second similar product is  B0009Z3MQK  average rating is  4.434426229508197
# -----------------------------------------------------------
# Based on product reviews, for  B00ZS1SRO2  average rating is  4.371134020618556
# The first similar product is  B00CMC6HCY  average rating is  4.32
# The second similar product is  B002BRZ8FW  average rating is  4.445544554455446
# -----------------------------------------------------------
# Based on product reviews, for  B00ZS2HFVW  average rating is  4.0
# The first similar product is  B0050SVGW8  average rating is  4.7375
# The second similar product is  B00WOK8Z74  average rating is  4.722222222222222
# -----------------------------------------------------------
# Based on product reviews, for  B00ZSDTIGG  average rating is  4.746666666666667
# The first similar product is  B002GJRQSC  average rating is  4.425
# The second similar product is  B00O9GW8TC  average rating is  4.897058823529412
# -----------------------------------------------------------
# Based on product reviews, for  B00ZSHRPN0  average rating is  3.6777777777777776
# The first similar product is  B0050SVGXM  average rating is  4.430232558139535
# The second similar product is  B00KVL0SIM  average rating is  3.5694444444444446
# -----------------------------------------------------------
# Based on product reviews, for  B010NCWJXK  average rating is  4.445378151260504
# The first similar product is  B005FDUSTA  average rating is  4.61
# The second similar product is  B00GGURQU0  average rating is  4.316326530612245
# -----------------------------------------------------------
# Based on product reviews, for  B0118GJKIW  average rating is  4.045454545454546
# The first similar product is  B00NNU07RU  average rating is  4.675675675675675
# The second similar product is  B00NMST9G8  average rating is  4.155339805825243
# -----------------------------------------------------------
# Based on product reviews, for  B011XO54MA  average rating is  4.5813953488372094
# The first similar product is  B00F2WNMGU  average rating is  4.854838709677419
# The second similar product is  B00KTNPYQS  average rating is  4.701754385964913
# -----------------------------------------------------------
# Based on product reviews, for  B0128UH1VU  average rating is  4.806451612903226
# The first similar product is  B00PIEHUDS  average rating is  4.773584905660377
# The second similar product is  B00PIEHU74  average rating is  4.754385964912281
# -----------------------------------------------------------
# Based on product reviews, for  B0128UH4HQ  average rating is  4.714285714285714
# The first similar product is  B00F3I2UFC  average rating is  4.9
# The second similar product is  B00Y074K3M  average rating is  4.794117647058823
# -----------------------------------------------------------
# Based on product reviews, for  B012DFI02O  average rating is  4.4363636363636365
# The first similar product is  B00KVP3OY8  average rating is  4.188679245283019
# The second similar product is  B00D96BJSO  average rating is  4.032258064516129
# -----------------------------------------------------------
# Based on product reviews, for  B012E58DFC  average rating is  4.375
# The first similar product is  B0050SYOOA  average rating is  4.542857142857143
# The second similar product is  B0056G1IYK  average rating is  4.673076923076923
# -----------------------------------------------------------
# Based on product reviews, for  B012F20ZU0  average rating is  4.576923076923077
# The first similar product is  B00X8XVJJ2  average rating is  4.173076923076923
# The second similar product is  B006VXPB9U  average rating is  4.764705882352941
# -----------------------------------------------------------
# Based on product reviews, for  B012F20ZY6  average rating is  4.7846153846153845
# The first similar product is  B001GIUWX0  average rating is  4.816666666666666
# The second similar product is  B00C710AZ0  average rating is  4.038961038961039
# -----------------------------------------------------------
# Based on product reviews, for  B012JMS4W2  average rating is  4.701492537313433
# The first similar product is  B00TS0UFOY  average rating is  4.754098360655738
# The second similar product is  B00F3I2UFC  average rating is  4.9
# -----------------------------------------------------------
# Based on product reviews, for  B012TRQKZA  average rating is  3.76056338028169
# The first similar product is  B000FDOTIQ  average rating is  3.76
# The second similar product is  B000QUYHIK  average rating is  4.291139240506329
# -----------------------------------------------------------
# Based on product reviews, for  B012UGC9F0  average rating is  4.569620253164557
# The first similar product is  B00E369SDM  average rating is  4.293333333333333
# The second similar product is  B009DYE3JI  average rating is  4.5636363636363635
# -----------------------------------------------------------
# Based on product reviews, for  B01307Q6ZC  average rating is  4.757142857142857
# The first similar product is  B0018QOWEU  average rating is  4.684210526315789
# The second similar product is  B007BKMGEU  average rating is  4.776119402985074
# -----------------------------------------------------------
# Based on product reviews, for  B01307QVCA  average rating is  4.811764705882353
# The first similar product is  B0085L2T0A  average rating is  4.2967032967032965
# The second similar product is  B000P297EI  average rating is  4.37037037037037
# -----------------------------------------------------------
# Based on product reviews, for  B0132YMS50  average rating is  4.91358024691358
# The first similar product is  B00KWHJ0KC  average rating is  4.811320754716981
# The second similar product is  B00A0SO0KS  average rating is  4.661538461538462
# -----------------------------------------------------------
# Based on product reviews, for  B0136JP9MA  average rating is  4.7073170731707314
# The first similar product is  B00EZKNSTQ  average rating is  4.338842975206612
# The second similar product is  B00LMRL00O  average rating is  4.3768115942028984
# -----------------------------------------------------------
# Based on product reviews, for  B0136JP9OS  average rating is  4.3023255813953485
# The first similar product is  B00TY9KYKE  average rating is  4.3875
# The second similar product is  B00NFXOQW2  average rating is  4.433333333333334
# -----------------------------------------------------------
# Based on product reviews, for  B0136JPA56  average rating is  4.235294117647059
# The first similar product is  B00FLLFJOU  average rating is  4.214285714285714
# The second similar product is  B00NMST9G8  average rating is  4.155339805825243
# -----------------------------------------------------------
# Based on product reviews, for  B013H0IRO0  average rating is  3.7870967741935484
# The first similar product is  B0022TNO7S  average rating is  4.177083333333333
# The second similar product is  B00WOK8YX4  average rating is  4.461538461538462
# -----------------------------------------------------------
# Based on product reviews, for  B013H0ISW6  average rating is  3.74025974025974
# The first similar product is  B00CMC6HZ6  average rating is  4.421875
# The second similar product is  B00HHIPQ98  average rating is  3.8289473684210527
# -----------------------------------------------------------
# Based on product reviews, for  B013HJ7FRG  average rating is  4.814814814814815
# The first similar product is  B00EC6W1O6  average rating is  4.9423076923076925
# The second similar product is  B00PIEHUDS  average rating is  4.773584905660377
# -----------------------------------------------------------
# Based on product reviews, for  B013HMN66M  average rating is  4.621145374449339
# The first similar product is  B00KVRNIQU  average rating is  4.617283950617284
# The second similar product is  B003O6EB70  average rating is  4.422053231939164
# -----------------------------------------------------------
# Based on product reviews, for  B013HSWF40  average rating is  3.8380952380952382
# The first similar product is  B00LZVNWIA  average rating is  4.329545454545454
# The second similar product is  B00EO2ECUY  average rating is  3.917525773195876
# -----------------------------------------------------------
# Based on product reviews, for  B013KK9JOO  average rating is  3.9298245614035086
# The first similar product is  B00ARD5410  average rating is  4.038461538461538
# The second similar product is  B006W3ZXEW  average rating is  3.984126984126984
# -----------------------------------------------------------
# Based on product reviews, for  B013P0HW7K  average rating is  3.642857142857143
# The first similar product is  B0029M6VKA  average rating is  4.442622950819672
# The second similar product is  B0000512IE  average rating is  4.596153846153846
# -----------------------------------------------------------
# Based on product reviews, for  B013X9HA7K  average rating is  4.228070175438597
# The first similar product is  B001TOQ8UW  average rating is  4.158878504672897
# The second similar product is  B006QRNKOO  average rating is  4.248
# -----------------------------------------------------------
# Based on product reviews, for  B014278KPS  average rating is  4.862745098039215
# The first similar product is  B00PIEHUDS  average rating is  4.773584905660377
# The second similar product is  B00Y074K3M  average rating is  4.794117647058823
# -----------------------------------------------------------
# Based on product reviews, for  B014KXMDPC  average rating is  4.595238095238095
# The first similar product is  B004UDLRMS  average rating is  3.318681318681319
# The second similar product is  B00CJXYU9S  average rating is  4.254237288135593
# -----------------------------------------------------------
# Based on product reviews, for  B014KXMLZ4  average rating is  4.923076923076923
# The first similar product is  B00O9GP95W  average rating is  4.8059701492537314
# The second similar product is  B00EC6W1O6  average rating is  4.9423076923076925
# -----------------------------------------------------------
# Based on product reviews, for  B014N4RTS4  average rating is  4.564102564102564
# The first similar product is  B00YC7DZP4  average rating is  4.597222222222222
# The second similar product is  B00AYABWYE  average rating is  4.426470588235294
# -----------------------------------------------------------
# Based on product reviews, for  B014PCUKJO  average rating is  3.8285714285714287
# The first similar product is  B00F4GSAYI  average rating is  4.38
# The second similar product is  B00LH6CBA8  average rating is  4.098039215686274
# -----------------------------------------------------------
# Based on product reviews, for  B014PZTAME  average rating is  4.015873015873016
# The first similar product is  B00HHJBG5A  average rating is  4.430769230769231
# The second similar product is  B00NFXOQW2  average rating is  4.433333333333334
# -----------------------------------------------------------
# Based on product reviews, for  B014R4ZXXI  average rating is  4.27027027027027
# The first similar product is  B00CXCCH1I  average rating is  3.5930232558139537
# The second similar product is  B002BRZ8FW  average rating is  4.445544554455446
# -----------------------------------------------------------
# Based on product reviews, for  B014R4ZZ0E  average rating is  4.815384615384615
# The first similar product is  B0050SYBL6  average rating is  4.402985074626866
# The second similar product is  B00LH6CBA8  average rating is  4.098039215686274
# -----------------------------------------------------------
# Based on product reviews, for  B014R50404  average rating is  4.92
# The first similar product is  B00LH6CBA8  average rating is  4.098039215686274
# The second similar product is  B00KVPC0O8  average rating is  4.288461538461538
# -----------------------------------------------------------
# Based on product reviews, for  B014SIVGAW  average rating is  4.4523809523809526
# The first similar product is  B002TK1PX0  average rating is  4.616
# The second similar product is  B00HN9LS48  average rating is  4.446808510638298
# -----------------------------------------------------------
# Based on product reviews, for  B014W3FGYU  average rating is  4.52808988764045
# The first similar product is  B00BBUCCKO  average rating is  4.301075268817204
# The second similar product is  B00AOIRCI6  average rating is  4.1866666666666665
# -----------------------------------------------------------
# Based on product reviews, for  B0151K6J9Y  average rating is  4.746031746031746
# The first similar product is  B00EC6W1O6  average rating is  4.9423076923076925
# The second similar product is  B00PIEHUDS  average rating is  4.773584905660377
# -----------------------------------------------------------
# Based on product reviews, for  B0156SN04I  average rating is  4.175438596491228
# The first similar product is  B004WLRR4K  average rating is  4.711538461538462
# The second similar product is  B0050SYZ2G  average rating is  4.237288135593221
# -----------------------------------------------------------
# Based on product reviews, for  B01574SORE  average rating is  4.2
# The first similar product is  B0050SXNHO  average rating is  4.848837209302325
# The second similar product is  B00E369SDM  average rating is  4.293333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B015HAL2OA  average rating is  4.3088235294117645
# The first similar product is  B00MMPB4RE  average rating is  4.611111111111111
# The second similar product is  B001AZFSEW  average rating is  3.7735849056603774
# -----------------------------------------------------------
# Based on product reviews, for  B015IX3X3E  average rating is  4.573529411764706
# The first similar product is  B00LMRL00O  average rating is  4.3768115942028984
# The second similar product is  B008U2XE9O  average rating is  4.153846153846154
# -----------------------------------------------------------
# Based on product reviews, for  B015TL6PCQ  average rating is  4.241379310344827
# The first similar product is  B00MMTKXTA  average rating is  4.041666666666667
# The second similar product is  B00NMST9G8  average rating is  4.155339805825243
# -----------------------------------------------------------
# Based on product reviews, for  B015WKY3IM  average rating is  3.96
# The first similar product is  B000UQCER6  average rating is  3.903225806451613
# The second similar product is  B002GJXAM8  average rating is  4.352941176470588
# -----------------------------------------------------------
# Based on product reviews, for  B015XC3B46  average rating is  4.166666666666667
# The first similar product is  B00OXT579S  average rating is  4.337209302325581
# The second similar product is  B005ZL5XRO  average rating is  4.627118644067797
# -----------------------------------------------------------
# Based on product reviews, for  B0160USMW6  average rating is  4.11864406779661
# The first similar product is  B00ARD5410  average rating is  4.038461538461538
# The second similar product is  B00S9SH7V0  average rating is  4.224137931034483
# -----------------------------------------------------------
# Based on product reviews, for  B0166QDJDQ  average rating is  4.170833333333333
# The first similar product is  B00KAED7OC  average rating is  4.397637795275591
# The second similar product is  B00DDXILBQ  average rating is  3.5475113122171944
# -----------------------------------------------------------
# Based on product reviews, for  B0166QDJZE  average rating is  4.396551724137931
# The first similar product is  B00DFT0WVU  average rating is  4.2772277227722775
# The second similar product is  B00KWF366S  average rating is  4.734848484848484
# -----------------------------------------------------------
# Based on product reviews, for  B016KBVBCS  average rating is  3.8993055555555554
# The first similar product is  B00O65I2VY  average rating is  4.314553990610329
# The second similar product is  B002B9XB0E  average rating is  4.548936170212766
# -----------------------------------------------------------
# Based on product reviews, for  B016MAK38U  average rating is  4.488
# The first similar product is  B00FWK8UWI  average rating is  4.184397163120567
# The second similar product is  B0068INSUM  average rating is  4.559139784946237
# -----------------------------------------------------------
# Based on product reviews, for  B016NZFGP4  average rating is  3.0441176470588234
# The first similar product is  B000FDDN2E  average rating is  4.771929824561403
# The second similar product is  B00B67ZS3U  average rating is  4.185185185185185
# -----------------------------------------------------------
# Based on product reviews, for  B016S5DC3M  average rating is  4.725
# The first similar product is  B00TS0UKE4  average rating is  4.693333333333333
# The second similar product is  B00KWHJ0KC  average rating is  4.811320754716981
# -----------------------------------------------------------
# Based on product reviews, for  B016Y3CTJQ  average rating is  4.422535211267606
# The first similar product is  B002EE4VQY  average rating is  4.471698113207547
# The second similar product is  B000VBB69M  average rating is  4.315068493150685
# -----------------------------------------------------------
# Based on product reviews, for  B016YQRYNY  average rating is  4.009345794392523
# The first similar product is  B00LV5XHIK  average rating is  4.086206896551724
# The second similar product is  B001E65P72  average rating is  4.6716417910447765
# -----------------------------------------------------------
# Based on product reviews, for  B0171RL3P0  average rating is  3.5849056603773586
# The first similar product is  B004AU0H4U  average rating is  4.754716981132075
# The second similar product is  B00ISW0TGW  average rating is  4.509090909090909
# -----------------------------------------------------------
# Based on product reviews, for  B017AGIDV4  average rating is  4.43298969072165
# The first similar product is  B00R9NWTQO  average rating is  4.393939393939394
# The second similar product is  B00B67ZTUW  average rating is  4.5638297872340425
# -----------------------------------------------------------
# Based on product reviews, for  B017L186MY  average rating is  4.167567567567567
# The first similar product is  B0022TNO7S  average rating is  4.177083333333333
# The second similar product is  B00DC9SWWE  average rating is  3.9047619047619047
# -----------------------------------------------------------
# Based on product reviews, for  B017L187LE  average rating is  4.13
# The first similar product is  B0085CA8NY  average rating is  4.179775280898877
# The second similar product is  B0056WJA30  average rating is  4.369565217391305
# -----------------------------------------------------------
# Based on product reviews, for  B017L187YG  average rating is  4.226027397260274
# The first similar product is  B00DTWEOZ8  average rating is  3.8217054263565893
# The second similar product is  B00KVHSNB0  average rating is  3.9
# -----------------------------------------------------------
# Based on product reviews, for  B017S3OPZM  average rating is  4.437185929648241
# The first similar product is  B005YR308S  average rating is  4.281609195402299
# The second similar product is  B000SQ5LQ4  average rating is  4.110429447852761
# -----------------------------------------------------------
# Based on product reviews, for  B017TFOZOA  average rating is  4.330882352941177
# The first similar product is  B001IK1BJ0  average rating is  4.1678832116788325
# The second similar product is  B001IK1BWC  average rating is  4.2109375
# -----------------------------------------------------------
# Based on product reviews, for  B017V6Y34E  average rating is  3.36231884057971
# The first similar product is  B0050SW33E  average rating is  4.019607843137255
# The second similar product is  B00000DMAQ  average rating is  4.686567164179104
# -----------------------------------------------------------
# Based on product reviews, for  B017W16ZNA  average rating is  4.3283582089552235
# The first similar product is  B003O6EBRA  average rating is  4.135135135135135
# The second similar product is  B00JDOX2SG  average rating is  3.792207792207792
# -----------------------------------------------------------
# Based on product reviews, for  B017W16ZUI  average rating is  4.62962962962963
# The first similar product is  B001BP4JY6  average rating is  4.14
# The second similar product is  B000038ABO  average rating is  4.314814814814815
# -----------------------------------------------------------
# Based on product reviews, for  B017W175SE  average rating is  4.610169491525424
# The first similar product is  B006P5RW3M  average rating is  4.03125
# The second similar product is  B004CVWETI  average rating is  4.597402597402597
# -----------------------------------------------------------
# Based on product reviews, for  B017W175Y8  average rating is  4.3106060606060606
# The first similar product is  B00H5V9S6E  average rating is  4.743589743589744
# The second similar product is  B00KWF366S  average rating is  4.734848484848484
# -----------------------------------------------------------
# Based on product reviews, for  B017W1771Y  average rating is  4.758454106280193
# The first similar product is  B00M049CG2  average rating is  4.34319526627219
# The second similar product is  B00C27SCC2  average rating is  3.88
# -----------------------------------------------------------
# Based on product reviews, for  B017WJY9V2  average rating is  4.833333333333333
# The first similar product is  B001O1OBFY  average rating is  4.5125
# The second similar product is  B000MJB1WU  average rating is  4.616666666666666
# -----------------------------------------------------------
# Based on product reviews, for  B017Y97NHM  average rating is  4.663157894736842
# The first similar product is  B00IPTUJ8G  average rating is  4.172043010752688
# The second similar product is  B00BAWXCP2  average rating is  4.685714285714286
# -----------------------------------------------------------
# Based on product reviews, for  B0186D1U74  average rating is  4.86
# The first similar product is  B00DVPMVIU  average rating is  4.633333333333334
# The second similar product is  B005EZ5GQY  average rating is  4.226415094339623
# -----------------------------------------------------------
# Based on product reviews, for  B018K6KV68  average rating is  4.119170984455959
# The first similar product is  B00BDS415I  average rating is  4.114583333333333
# The second similar product is  B00BFOEY4I  average rating is  4.005235602094241
# -----------------------------------------------------------
# Based on product reviews, for  B018RKS1TG  average rating is  4.368421052631579
# The first similar product is  B00NMS0YYO  average rating is  4.412371134020619
# The second similar product is  B004UDB9SA  average rating is  3.7874015748031495
# -----------------------------------------------------------
# Based on product reviews, for  B018V3ISJ2  average rating is  4.507352941176471
# The first similar product is  B002I0K956  average rating is  4.831932773109243
# The second similar product is  B00CXCCI8A  average rating is  4.2809917355371905
# -----------------------------------------------------------
# Based on product reviews, for  B018WJZKBY  average rating is  4.372881355932203
# The first similar product is  B0028IBTL6  average rating is  4.527272727272727
# The second similar product is  B00DCBDNW6  average rating is  3.8846153846153846
# -----------------------------------------------------------
# Based on product reviews, for  B0191J0RXA  average rating is  4.693069306930693
# The first similar product is  B00NOBX1OO  average rating is  4.63013698630137
# The second similar product is  B001TOMR6Q  average rating is  4.325
# -----------------------------------------------------------
# Based on product reviews, for  B0194VWT5Y  average rating is  4.579710144927536
# The first similar product is  B0026FCARI  average rating is  4.490909090909091
# The second similar product is  B00KWFCUNS  average rating is  4.238095238095238
# -----------------------------------------------------------
# Based on product reviews, for  B019GNMP1I  average rating is  4.44
# The first similar product is  B0053BQREE  average rating is  3.864406779661017
# The second similar product is  B0050SW33E  average rating is  4.019607843137255
# -----------------------------------------------------------
# Based on product reviews, for  B019GNMT9Q  average rating is  4.403225806451613
# The first similar product is  B001PB9J14  average rating is  3.9322033898305087
# The second similar product is  B00F4GSAYI  average rating is  4.38
# -----------------------------------------------------------
# Based on product reviews, for  B019H5II8Y  average rating is  3.971830985915493
# The first similar product is  B0041HROGG  average rating is  4.174418604651163
# The second similar product is  B002C1AUP0  average rating is  4.693548387096774
# -----------------------------------------------------------
# Based on product reviews, for  B019J6RYCW  average rating is  4.464788732394366
# The first similar product is  B0050SX1JO  average rating is  4.534883720930233
# The second similar product is  B00CD90R72  average rating is  4.378787878787879
# -----------------------------------------------------------
# Based on product reviews, for  B019OB663A  average rating is  4.552763819095477
# The first similar product is  B0091I20E6  average rating is  4.013698630136986
# The second similar product is  B00BFOEY3Y  average rating is  4.06
# -----------------------------------------------------------
# Based on product reviews, for  B01A99RRL6  average rating is  4.258620689655173
# The first similar product is  B00CJD4HD2  average rating is  4.226666666666667
# The second similar product is  B001NTFATI  average rating is  4.383561643835616
# -----------------------------------------------------------
# Based on product reviews, for  B01A9UATJC  average rating is  4.627906976744186
# The first similar product is  B00F6FJCMQ  average rating is  4.6415094339622645
# The second similar product is  B00LV5XHIK  average rating is  4.086206896551724
# -----------------------------------------------------------
# Based on product reviews, for  B01AC3ZD06  average rating is  4.823529411764706
# The first similar product is  B00420K18K  average rating is  4.468468468468468
# The second similar product is  B00K1JBLNA  average rating is  4.269662921348314
# -----------------------------------------------------------
# Based on product reviews, for  B01AC3ZD2O  average rating is  4.533333333333333
# The first similar product is  B00WOK8Z74  average rating is  4.722222222222222
# The second similar product is  B00KVPC0O8  average rating is  4.288461538461538
# -----------------------------------------------------------
# Based on product reviews, for  B01AC3ZDCE  average rating is  4.862068965517241
# The first similar product is  B003O6E800  average rating is  4.757894736842105
# The second similar product is  B00KOOUW82  average rating is  4.371900826446281
# -----------------------------------------------------------
# Based on product reviews, for  B01AC3ZE5K  average rating is  4.567164179104478
# The first similar product is  B000TUZCQI  average rating is  4.756756756756757
# The second similar product is  B00ENRTB10  average rating is  3.693548387096774
# -----------------------------------------------------------
# Based on product reviews, for  B01AC3ZGRG  average rating is  4.4935064935064934
# The first similar product is  B00JUFSH6U  average rating is  4.493150684931507
# The second similar product is  B00RHI62OG  average rating is  4.554054054054054
# -----------------------------------------------------------
# Based on product reviews, for  B01APA8D2G  average rating is  3.9857142857142858
# The first similar product is  B0055QZ216  average rating is  4.341772151898734
# The second similar product is  B004RJJMBI  average rating is  4.278688524590164
# -----------------------------------------------------------
# Based on product reviews, for  B01B298Q1W  average rating is  3.235294117647059
# The first similar product is  B0000A8VBZ  average rating is  4.176470588235294
# The second similar product is  B002BRYXRQ  average rating is  4.014084507042254
# -----------------------------------------------------------
# Based on product reviews, for  B01B61X1UC  average rating is  4.84375
# The first similar product is  B00DCBDNW6  average rating is  3.8846153846153846
# The second similar product is  B005UDTTQ8  average rating is  4.470588235294118
# -----------------------------------------------------------
# Based on product reviews, for  B01BBKYM3I  average rating is  4.492307692307692
# The first similar product is  B008U5ZM6E  average rating is  4.051282051282051
# The second similar product is  B00BHSTXV6  average rating is  4.054545454545455
# -----------------------------------------------------------
# Based on product reviews, for  B01BEELH1G  average rating is  4.903846153846154
# The first similar product is  B002C5BMFI  average rating is  3.6818181818181817
# The second similar product is  B003ANMB6A  average rating is  3.6153846153846154
# -----------------------------------------------------------
# Based on product reviews, for  B01C93CWSI  average rating is  4.712837837837838
# The first similar product is  B0053B66KE  average rating is  4.77
# The second similar product is  B00K848IH0  average rating is  4.734082397003745
# -----------------------------------------------------------
# Based on product reviews, for  B01C93CWU6  average rating is  4.606271777003484
# The first similar product is  B00K848IH0  average rating is  4.734082397003745
# The second similar product is  B0053B66KE  average rating is  4.77
# -----------------------------------------------------------
# Based on product reviews, for  B01CEFEMFW  average rating is  4.572815533980583
# The first similar product is  B005HGCNU2  average rating is  4.261261261261262
# The second similar product is  B00CJD4HD2  average rating is  4.226666666666667
# -----------------------------------------------------------
# Based on product reviews, for  B01CHU4IY4  average rating is  4.122448979591836
# The first similar product is  B00NMS0YYO  average rating is  4.412371134020619
# The second similar product is  B00JKM06EO  average rating is  4.463414634146342
# -----------------------------------------------------------
# Based on product reviews, for  B01CINIAKS  average rating is  3.6964285714285716
# The first similar product is  B00B29S1JK  average rating is  4.037735849056604
# The second similar product is  B00198ZHC8  average rating is  3.48
# -----------------------------------------------------------
# Based on product reviews, for  B01CJI62WA  average rating is  4.688311688311688
# The first similar product is  B00C710AZ0  average rating is  4.038961038961039
# The second similar product is  B00ERDGMT4  average rating is  4.661971830985915
# -----------------------------------------------------------
# Based on product reviews, for  B01CKGI0XA  average rating is  4.538461538461538
# The first similar product is  B00DFT92EI  average rating is  3.830508474576271
# The second similar product is  B00KVPC0O8  average rating is  4.288461538461538
# -----------------------------------------------------------
# Based on product reviews, for  B01CKGI4RM  average rating is  4.2125
# The first similar product is  B007BGUGVO  average rating is  4.080645161290323
# The second similar product is  B004FUI84G  average rating is  4.291666666666667
# -----------------------------------------------------------
# Based on product reviews, for  B01CR058OS  average rating is  4.589285714285714
# The first similar product is  B0029MAXR2  average rating is  4.4411764705882355
# The second similar product is  B00KVPC0O8  average rating is  4.288461538461538
# -----------------------------------------------------------
# Based on product reviews, for  B01CR05F5K  average rating is  4.511904761904762
# The first similar product is  B0085L2T0A  average rating is  4.2967032967032965
# The second similar product is  B00CMC6HZ6  average rating is  4.421875
# -----------------------------------------------------------
# Based on product reviews, for  B01D63UU52  average rating is  4.466019417475728
# The first similar product is  B00IRHE892  average rating is  4.4576271186440675
# The second similar product is  B005HGCNU2  average rating is  4.261261261261262
# -----------------------------------------------------------
# Based on product reviews, for  B01DJPA9YE  average rating is  4.239130434782608
# The first similar product is  B00BY0G0YU  average rating is  4.787610619469026
# The second similar product is  B002BRZ79E  average rating is  3.730769230769231
# -----------------------------------------------------------
# Based on product reviews, for  B01DPS4QQ2  average rating is  3.6923076923076925
# The first similar product is  B00NQHO7SK  average rating is  3.963636363636364
# The second similar product is  B00MNPDMEQ  average rating is  3.0784313725490198
# -----------------------------------------------------------
# Based on product reviews, for  B01DPUVMNU  average rating is  3.1866666666666665
# The first similar product is  B00ZE361SS  average rating is  3.8636363636363638
# The second similar product is  B001PB9J14  average rating is  3.9322033898305087
# -----------------------------------------------------------
# Based on product reviews, for  B01E8RS598  average rating is  4.271186440677966
# The first similar product is  B00NQHO7SK  average rating is  3.963636363636364
# The second similar product is  B00YXO5UXG  average rating is  3.984375
# -----------------------------------------------------------
# Based on product reviews, for  B01EZA0D8O  average rating is  3.719298245614035
# The first similar product is  B00CMC6HCY  average rating is  4.32
# The second similar product is  B00KBZHSV8  average rating is  3.8
# -----------------------------------------------------------
# Based on product reviews, for  B01EZA0D8Y  average rating is  3.5374149659863945
# The first similar product is  B00K31C478  average rating is  3.8739495798319328
# The second similar product is  B00K308KF4  average rating is  3.9357798165137616
# -----------------------------------------------------------
# Based on product reviews, for  B01EZA0DEI  average rating is  3.443708609271523
# The first similar product is  B00K308KF4  average rating is  3.9357798165137616
# The second similar product is  B00K31C478  average rating is  3.8739495798319328
# -----------------------------------------------------------
# Based on product reviews, for  B01EZAA2ZI  average rating is  3.220720720720721
# The first similar product is  B00K308KF4  average rating is  3.9357798165137616
# The second similar product is  B007XVTR12  average rating is  3.651006711409396
# -----------------------------------------------------------
# Based on product reviews, for  B01F04ZDO8  average rating is  4.543859649122807
# The first similar product is  B00ENRTB10  average rating is  3.693548387096774
# The second similar product is  B00KWHJ2JQ  average rating is  4.519230769230769
# -----------------------------------------------------------
# Based on product reviews, for  B01F84ZHMI  average rating is  4.17910447761194
# The first similar product is  B00JUFSH9M  average rating is  4.066115702479339
# The second similar product is  B00C710AQO  average rating is  4.305882352941176
# -----------------------------------------------------------
# Based on product reviews, for  B01F84ZRSW  average rating is  3.9157894736842107
# The first similar product is  B00XWE656O  average rating is  4.203125
# The second similar product is  B00CMC6HZ6  average rating is  4.421875
# -----------------------------------------------------------
# Based on product reviews, for  B01F9HMO2K  average rating is  4.277511961722488
# The first similar product is  B00M049CG2  average rating is  4.34319526627219
# The second similar product is  B002I096Q4  average rating is  3.9622641509433962
# -----------------------------------------------------------
# Based on product reviews, for  B01F9HMO9S  average rating is  4.219858156028369
# The first similar product is  B00KVHSNB0  average rating is  3.9
# The second similar product is  B002BSA1MQ  average rating is  4.299319727891157
# -----------------------------------------------------------
# Based on product reviews, for  B01FWLGWHQ  average rating is  3.246153846153846
# The first similar product is  B001AZFSEW  average rating is  3.7735849056603774
# The second similar product is  B0053BQREE  average rating is  3.864406779661017
# -----------------------------------------------------------
# Based on product reviews, for  B01GD490UM  average rating is  4.602409638554217
# The first similar product is  B00J6DLPLK  average rating is  4.134328358208955
# The second similar product is  B003O680ZY  average rating is  4.2988505747126435
# -----------------------------------------------------------
# Based on product reviews, for  B01GD4928C  average rating is  3.985074626865672
# The first similar product is  B00DFT92EI  average rating is  3.830508474576271
# The second similar product is  B00000I1BR  average rating is  4.413793103448276
# -----------------------------------------------------------
# Based on product reviews, for  B01GKF7T9S  average rating is  4.216867469879518
# The first similar product is  B00H5V9S6E  average rating is  4.743589743589744
# The second similar product is  B00KWF366S  average rating is  4.734848484848484
# -----------------------------------------------------------
# Based on product reviews, for  B01GKF824Y  average rating is  4.1625
# The first similar product is  B002BRZ8FW  average rating is  4.445544554455446
# The second similar product is  B00W435C0Y  average rating is  4.195402298850575
# -----------------------------------------------------------
# Based on product reviews, for  B01GKGVI8K  average rating is  4.117647058823529
# The first similar product is  B000AB603U  average rating is  3.5964912280701755
# The second similar product is  B000067O0Q  average rating is  4.1875
# -----------------------------------------------------------
# Based on product reviews, for  B01GKGVI8U  average rating is  4.540084388185654
# The first similar product is  B00CXCCB64  average rating is  3.801526717557252
# The second similar product is  B003O6EB70  average rating is  4.422053231939164
# -----------------------------------------------------------
# Based on product reviews, for  B01GKGVIB2  average rating is  4.427586206896552
# The first similar product is  B00KVHSNB0  average rating is  3.9
# The second similar product is  B000TI836G  average rating is  3.740740740740741
# -----------------------------------------------------------
# Based on product reviews, for  B01GKH5Q9G  average rating is  4.351851851851852
# The first similar product is  B00KPY1GX6  average rating is  4.72093023255814
# The second similar product is  B00MU1YEYU  average rating is  4.296610169491525
# -----------------------------------------------------------
# Based on product reviews, for  B01GKHJP98  average rating is  4.480392156862745
# The first similar product is  B00009ECGK  average rating is  4.682352941176471
# The second similar product is  B000TG72PG  average rating is  4.510869565217392
# -----------------------------------------------------------
# Based on product reviews, for  B01GKHJPG6  average rating is  4.896103896103896
# The first similar product is  B002HJYKG2  average rating is  4.683333333333334
# The second similar product is  B00ERDGMO4  average rating is  4.734375
# -----------------------------------------------------------
# Based on product reviews, for  B01GOK34SO  average rating is  4.222222222222222
# The first similar product is  B000B6MLSM  average rating is  4.324324324324325
# The second similar product is  B00005O0I9  average rating is  4.302631578947368
# -----------------------------------------------------------
# Based on product reviews, for  B01GOOFYG0  average rating is  4.830188679245283
# The first similar product is  B00K2O54V4  average rating is  4.3559322033898304
# The second similar product is  B00KVPC0O8  average rating is  4.288461538461538
# -----------------------------------------------------------
# Based on product reviews, for  B01GP9BDJG  average rating is  3.8095238095238093
# The first similar product is  B00SLBG3S8  average rating is  3.830769230769231
# The second similar product is  B00EDHEW32  average rating is  3.8051948051948052
# -----------------------------------------------------------
# Based on product reviews, for  B01GVE4YB4  average rating is  4.111111111111111
# The first similar product is  B005HN5LKY  average rating is  3.5272727272727273
# The second similar product is  B00F4CDIR6  average rating is  4.803571428571429
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3GM7I  average rating is  4.277777777777778
# The first similar product is  B00MMTKXTA  average rating is  4.041666666666667
# The second similar product is  B00IIHU44E  average rating is  4.338709677419355
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3LR8M  average rating is  3.6338028169014085
# The first similar product is  B00TDM91CY  average rating is  4.208333333333333
# The second similar product is  B00CMQTUCE  average rating is  3.8524590163934427
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3LRD2  average rating is  4.59047619047619
# The first similar product is  B000MUW98O  average rating is  4.360655737704918
# The second similar product is  B00FRD9MUO  average rating is  4.761363636363637
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3LREG  average rating is  4.82
# The first similar product is  B003O6E7DI  average rating is  4.672413793103448
# The second similar product is  B003RS8HG6  average rating is  4.339285714285714
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3NY5Q  average rating is  3.331730769230769
# The first similar product is  B002BSC4ZS  average rating is  3.9346733668341707
# The second similar product is  B000K9OP2A  average rating is  4.113636363636363
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3ODBU  average rating is  4.4914529914529915
# The first similar product is  B00WOK8YX4  average rating is  4.461538461538462
# The second similar product is  B00C27SCC2  average rating is  3.88
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3OFHM  average rating is  3.5873015873015874
# The first similar product is  B003RS8HG6  average rating is  4.339285714285714
# The second similar product is  B004P6IVPQ  average rating is  4.254901960784314
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3OHMK  average rating is  3.789473684210526
# The first similar product is  B00BQWTGIS  average rating is  3.449275362318841
# The second similar product is  B002I0K6Q8  average rating is  3.3493975903614457
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3P9PE  average rating is  4.603351955307263
# The first similar product is  B001NX6GBK  average rating is  4.128571428571429
# The second similar product is  B000FQ2GUQ  average rating is  4.67741935483871
# -----------------------------------------------------------
# Based on product reviews, for  B01GW3POY0  average rating is  4.490272373540856
# The first similar product is  B000B69E9G  average rating is  4.4972972972972975
# The second similar product is  B0050SY4DG  average rating is  3.7846153846153845
# -----------------------------------------------------------
# Based on product reviews, for  B01GW8VG7O  average rating is  4.689655172413793
# The first similar product is  B000OYMSL6  average rating is  3.8840579710144927
# The second similar product is  B000UQAUWW  average rating is  3.816666666666667
# -----------------------------------------------------------
# Based on product reviews, for  B01GW8XLCM  average rating is  4.440677966101695
# The first similar product is  B000034DMG  average rating is  4.777777777777778
# The second similar product is  B00CJXYU9S  average rating is  4.254237288135593
# -----------------------------------------------------------
# Based on product reviews, for  B01GW8YDLK  average rating is  4.705882352941177
# The first similar product is  B00005JC8D  average rating is  3.7435897435897436
# The second similar product is  B00KXAGTV6  average rating is  4.019230769230769
# -----------------------------------------------------------
# Based on product reviews, for  B01H482N6E  average rating is  3.7142857142857144
# The first similar product is  B004AU0H4U  average rating is  4.754716981132075
# The second similar product is  B00ARMQ7VM  average rating is  4.428571428571429
# -----------------------------------------------------------
# Based on product reviews, for  B01H6SM5CY  average rating is  4.28
# The first similar product is  B00NQHO7SK  average rating is  3.963636363636364
# The second similar product is  B001E45XT4  average rating is  4.049180327868853
# -----------------------------------------------------------
